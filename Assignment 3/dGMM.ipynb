# %%
import numpy as np
import struct
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
def load_images(file_path):
    """
    Load MNIST images from the IDX file format.
    
    Parameters:
    - file_path: str, path to the idx3-ubyte file
    
    Returns:
    - images: numpy.ndarray, shape (num_images, 28*28)
    """
    with open(file_path, 'rb') as f:
        # Read the magic number and dimensions
        magic, num_images, rows, cols = struct.unpack('>IIII', f.read(16))
        if magic != 2051:
            raise ValueError(f'Invalid magic number {magic} in image file: {file_path}')
        
        # Read the image data
        image_data = f.read()
        images = np.frombuffer(image_data, dtype=np.uint8)
        images = images.reshape(num_images, rows * cols)
        return images

def load_labels(file_path):
    """
    Load MNIST labels from the IDX file format.
    
    Parameters:
    - file_path: str, path to the idx1-ubyte file
    
    Returns:
    - labels: numpy.ndarray, shape (num_labels,)
    """
    with open(file_path, 'rb') as f:
        # Read the magic number and number of labels
        magic, num_labels = struct.unpack('>II', f.read(8))
        if magic != 2049:
            raise ValueError(f'Invalid magic number {magic} in label file: {file_path}')
        
        # Read the label data
        label_data = f.read()
        labels = np.frombuffer(label_data, dtype=np.uint8)
        return labels

# %%
# Paths to your MNIST files
train_images_path = 'data/train-images.idx3-ubyte'
train_labels_path = 'data/train-labels.idx1-ubyte'
test_images_path = 'data/t10k-images.idx3-ubyte'
test_labels_path = 'data/t10k-labels.idx1-ubyte'

# Load the data
X_train = load_images(train_images_path)
y_train = load_labels(train_labels_path)
X_test = load_images(test_images_path)
y_test = load_labels(test_labels_path)

# %%
# Normalize the data
X_train = X_train.astype(np.float64) / 255.0
X_test = X_test.astype(np.float64) / 255.0

# %%
# Apply PCA to reduce dimensionality to 20
pca = PCA(n_components=20, random_state=42)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
def initialize_gmm(X, K):

    #Initialize GMM parameters.
    num_samples, num_features = X.shape
    # Initialize means by randomly selecting K data points
    indices = np.random.choice(num_samples, K, replace=False)
    means = X[indices]
    # Initialize variances to the variance of the data
    variances = np.var(X, axis=0) + 1e-6  # Add a small value to prevent division by zero
    variances = np.tile(variances, (K, 1))
    # Initialize weights equally
    weights = np.full(K, 1 / K)
    return means, variances, weights

def compute_gaussian_density(X, means, variances):
    
    #Compute the Gaussian density for each data point and each component.
    num_samples, num_features = X.shape
    K = means.shape[0]
    densities = np.zeros((num_samples, K))
  

    for k in range(K):
        # Compute the exponent term
        exponent = -0.5 * np.sum(((X - means[k]) ** 2) / variances[k], axis=1)
        # Compute the coefficient term
        coef = 1 / np.sqrt((2 * np.pi) ** num_features * np.prod(variances[k]))
        densities[:, k] = coef * np.exp(exponent)
    
    return densities

def em_gmm(X, K, max_iters=500, tol=1e-5):
    #Perform EM algorithm to fit a diagonal GMM.
    
    means, variances, weights = initialize_gmm(X, K)
    log_likelihood = 0  #tracks the log probability as a debug tool
    for iteration in range(max_iters):
        # E-step: compute responsibilities
        densities = compute_gaussian_density(X, means, variances)
        weighted_densities = densities * weights
        total_density = np.sum(weighted_densities, axis=1, keepdims=True)
        responsibilities = weighted_densities / total_density  
        
        # M-step: update parameters
        Nk = np.sum(responsibilities, axis=0)  
        weights = Nk / X.shape[0]  
        means = (responsibilities.T @ X) / Nk[:, np.newaxis] 
        
        for k in range(K):
            diff = X - means[k]
            variances[k] = np.sum(responsibilities[:, k][:, np.newaxis] * (diff ** 2), axis=0) / Nk[k]
            variances[k][variances[k] < 1e-6] = 1e-6  # Prevent variances from becoming too small
       
        # Compute log likelihood as a debug tool
        new_log_likelihood = np.sum(np.log(total_density + 1e-300))  # Add small value to prevent log(0)
        
        if np.abs(new_log_likelihood - log_likelihood) < tol:
            print(f"  Converged at iteration {iteration+1}")
            break
        log_likelihood = new_log_likelihood
        
        if (iteration + 1) % 10 == 0 or iteration == 0:
            print(f"  Iteration {iteration+1}, Log Likelihood: {log_likelihood:.4f}")
        
    return means, variances, weights

# %%
def compute_class_priors(y_train, class_labels):
    
    #Compute the prior probabilities for each class.
    class_priors = np.array([np.mean(y_train == c) for c in class_labels])
    return class_priors

def classify_test_data(X_test, class_labels, gmm_models, class_priors):
    #Classify test data using the fitted GMM models and Bayes classifier.
 
    num_test = X_test.shape[0]
    num_classes = len(class_labels)
    log_probs = np.zeros((num_test, num_classes))
    
    for idx, c in enumerate(class_labels):
        means, variances, weights = gmm_models[c]
        densities = compute_gaussian_density(X_test, means, variances)  
        weighted_densities = densities * weights 
        p_x_given_c = np.sum(weighted_densities, axis=1)  
        # To prevent log(0), add a small epsilon
        p_x_given_c = np.maximum(p_x_given_c, 1e-300)
        log_p_x_given_c = np.log(p_x_given_c)
        log_prior = np.log(class_priors[idx])
        log_probs[:, idx] = log_prior + log_p_x_given_c
    
    # Predict the class with the highest log probability
    y_pred = class_labels[np.argmax(log_probs, axis=1)]
    return y_pred

# %%
class_labels = np.unique(y_train)
class_priors = compute_class_priors(y_train, class_labels)


K_values = [5, 10, 20, 30]


error_rates = {}

for K in K_values:
    print(f"\nFitting GMMs with K={K} components per class...")
    gmm_models = {}
    for c in class_labels:
        print(f"  Fitting GMM for class {c}...")
        X_c = X_train_pca[y_train == c]
        means, variances, weights = em_gmm(X_c, K, max_iters=500, tol=1e-5)
        gmm_models[c] = (means, variances, weights)
    print("GMMs fitted.")

    # Classify test data
    print("Classifying test data...")
    y_pred = classify_test_data(X_test_pca, class_labels, gmm_models, class_priors)

    # Compute error rate
    error_rate = np.mean(y_pred != y_test)
    error_rates[K] = error_rate
    print(f"Error rate for K={K}: {error_rate:.4f}")
# Out:
# Fitting GMMs with K=5 components per class...
#   Fitting GMM for class 0...
#   Iteration 1, Log Likelihood: -210956.9490
#   Iteration 10, Log Likelihood: -161929.7184
#   Iteration 20, Log Likelihood: -161508.4293
#   Iteration 30, Log Likelihood: -161468.8365
#   Iteration 40, Log Likelihood: -161463.4028
#   Iteration 50, Log Likelihood: -161462.9064
#   Iteration 60, Log Likelihood: -161462.8697
#   Iteration 70, Log Likelihood: -161462.8670
#   Converged at iteration 78
#   Fitting GMM for class 1...
#   Iteration 1, Log Likelihood: -134373.6901
#   Iteration 10, Log Likelihood: -89126.1209
#   Iteration 20, Log Likelihood: -87738.6170
#   Iteration 30, Log Likelihood: -86841.3846
#   Iteration 40, Log Likelihood: -86575.2302
#   Iteration 50, Log Likelihood: -86496.2659
#   Iteration 60, Log Likelihood: -86486.2672
#   Iteration 70, Log Likelihood: -86484.9583
#   Iteration 80, Log Likelihood: -86484.7787
#   Iteration 90, Log Likelihood: -86484.7543
#   Iteration 100, Log Likelihood: -86484.7510
#   Iteration 110, Log Likelihood: -86484.7505
#   Converged at iteration 113
#   Fitting GMM for class 2...
#   Iteration 1, Log Likelihood: -211020.7737
#   Iteration 10, Log Likelihood: -168556.3775
#   Iteration 20, Log Likelihood: -166687.8233
#   Iteration 30, Log Likelihood: -166161.7348
#   Iteration 40, Log Likelihood: -166113.1994
#   Iteration 50, Log Likelihood: -166097.4240
#   Iteration 60, Log Likelihood: -166092.8805
#   Iteration 70, Log Likelihood: -166091.5104
#   Iteration 80, Log Likelihood: -166091.0950
#   Iteration 90, Log Likelihood: -166090.9733
#   Iteration 100, Log Likelihood: -166090.9386
#   Iteration 110, Log Likelihood: -166090.9288
#   Iteration 120, Log Likelihood: -166090.9261
#   Iteration 130, Log Likelihood: -166090.9253
#   Iteration 140, Log Likelihood: -166090.9251
#   Converged at iteration 141
#   Fitting GMM for class 3...
#   Iteration 1, Log Likelihood: -201048.0946
#   Iteration 10, Log Likelihood: -167624.2947
#   Iteration 20, Log Likelihood: -167547.9386
#   Iteration 30, Log Likelihood: -167531.7524
#   Iteration 40, Log Likelihood: -167528.3110
#   Iteration 50, Log Likelihood: -167526.2662
#   Iteration 60, Log Likelihood: -167524.6191
#   Iteration 70, Log Likelihood: -167523.5078
#   Iteration 80, Log Likelihood: -167522.9547
#   Iteration 90, Log Likelihood: -167522.7459
#   Iteration 100, Log Likelihood: -167522.6803
#   Iteration 110, Log Likelihood: -167522.6616
#   Iteration 120, Log Likelihood: -167522.6565
#   Iteration 130, Log Likelihood: -167522.6551
#   Iteration 140, Log Likelihood: -167522.6548
#   Converged at iteration 146
#   Fitting GMM for class 4...
#   Iteration 1, Log Likelihood: -197240.0526
#   Iteration 10, Log Likelihood: -152428.9510
#   Iteration 20, Log Likelihood: -152272.5744
#   Iteration 30, Log Likelihood: -152254.6728
#   Iteration 40, Log Likelihood: -152252.2694
#   Iteration 50, Log Likelihood: -152252.0490
#   Iteration 60, Log Likelihood: -152252.0267
#   Iteration 70, Log Likelihood: -152252.0244
#   Converged at iteration 79
#   Fitting GMM for class 5...
#   Iteration 1, Log Likelihood: -191766.6406
#   Iteration 10, Log Likelihood: -146991.8531
#   Iteration 20, Log Likelihood: -146370.6111
#   Iteration 30, Log Likelihood: -145618.0788
#   Iteration 40, Log Likelihood: -145415.5794
#   Iteration 50, Log Likelihood: -145087.0466
#   Iteration 60, Log Likelihood: -144857.6640
#   Iteration 70, Log Likelihood: -144800.1108
#   Iteration 80, Log Likelihood: -144792.1448
#   Iteration 90, Log Likelihood: -144790.8371
#   Iteration 100, Log Likelihood: -144790.6228
#   Iteration 110, Log Likelihood: -144790.5917
#   Iteration 120, Log Likelihood: -144790.5875
#   Iteration 130, Log Likelihood: -144790.5870
#   Converged at iteration 133
#   Fitting GMM for class 6...
#   Iteration 1, Log Likelihood: -184919.9299
#   Iteration 10, Log Likelihood: -149873.5032
#   Iteration 20, Log Likelihood: -149550.6687
#   Iteration 30, Log Likelihood: -149464.8550
#   Iteration 40, Log Likelihood: -149459.5060
#   Iteration 50, Log Likelihood: -149456.5745
#   Iteration 60, Log Likelihood: -149427.4235
#   Iteration 70, Log Likelihood: -148834.6546
#   Iteration 80, Log Likelihood: -148696.8686
#   Iteration 90, Log Likelihood: -148608.0964
#   Iteration 100, Log Likelihood: -148309.4069
#   Iteration 110, Log Likelihood: -148161.5051
#   Iteration 120, Log Likelihood: -148114.8131
#   Iteration 130, Log Likelihood: -148098.5150
#   Iteration 140, Log Likelihood: -148093.7843
#   Iteration 150, Log Likelihood: -148093.2911
#   Iteration 160, Log Likelihood: -148093.2600
#   Iteration 170, Log Likelihood: -148093.2581
#   Converged at iteration 175
#   Fitting GMM for class 7...
#   Iteration 1, Log Likelihood: -186229.2376
#   Iteration 10, Log Likelihood: -152794.6218
#   Iteration 20, Log Likelihood: -152732.8413
#   Iteration 30, Log Likelihood: -152672.0070
#   Iteration 40, Log Likelihood: -152586.5218
#   Iteration 50, Log Likelihood: -152485.4399
#   Iteration 60, Log Likelihood: -152406.3075
#   Iteration 70, Log Likelihood: -152361.1691
#   Iteration 80, Log Likelihood: -152354.6850
#   Iteration 90, Log Likelihood: -152354.0774
#   Iteration 100, Log Likelihood: -152353.9946
#   Iteration 110, Log Likelihood: -152353.9822
#   Iteration 120, Log Likelihood: -152353.9803
#   Iteration 130, Log Likelihood: -152353.9800
#   Converged at iteration 131
#   Fitting GMM for class 8...
#   Iteration 1, Log Likelihood: -187977.4236
#   Iteration 10, Log Likelihood: -155799.4394
#   Iteration 20, Log Likelihood: -155457.6849
#   Iteration 30, Log Likelihood: -155221.2374
#   Iteration 40, Log Likelihood: -155194.1621
#   Iteration 50, Log Likelihood: -155183.9954
#   Iteration 60, Log Likelihood: -155177.8131
#   Iteration 70, Log Likelihood: -155173.5478
#   Iteration 80, Log Likelihood: -155171.1421
#   Iteration 90, Log Likelihood: -155169.9865
#   Iteration 100, Log Likelihood: -155169.4173
#   Iteration 110, Log Likelihood: -155169.1181
#   Iteration 120, Log Likelihood: -155168.9530
#   Iteration 130, Log Likelihood: -155168.8590
#   Iteration 140, Log Likelihood: -155168.8045
#   Iteration 150, Log Likelihood: -155168.7724
#   Iteration 160, Log Likelihood: -155168.7532
#   Iteration 170, Log Likelihood: -155168.7417
#   Iteration 180, Log Likelihood: -155168.7347
#   Iteration 190, Log Likelihood: -155168.7305
#   Iteration 200, Log Likelihood: -155168.7279
#   Iteration 210, Log Likelihood: -155168.7263
#   Iteration 220, Log Likelihood: -155168.7253
#   Iteration 230, Log Likelihood: -155168.7247
#   Iteration 240, Log Likelihood: -155168.7244
#   Iteration 250, Log Likelihood: -155168.7241
#   Iteration 260, Log Likelihood: -155168.7240
#   Converged at iteration 263
#   Fitting GMM for class 9...
#   Iteration 1, Log Likelihood: -192709.8919
#   Iteration 10, Log Likelihood: -150263.5128
#   Iteration 20, Log Likelihood: -147747.9549
#   Iteration 30, Log Likelihood: -147602.0266
#   Iteration 40, Log Likelihood: -147592.4509
#   Iteration 50, Log Likelihood: -147592.3145
#   Iteration 60, Log Likelihood: -147592.3120
#   Converged at iteration 64
# GMMs fitted.
# Classifying test data...
# Error rate for K=5: 0.0882
#
# Fitting GMMs with K=10 components per class...
#   Fitting GMM for class 0...
#   Iteration 1, Log Likelihood: -194531.6508
#   Iteration 10, Log Likelihood: -155714.9678
#   Iteration 20, Log Likelihood: -154731.9699
#   Iteration 30, Log Likelihood: -154129.8643
#   Iteration 40, Log Likelihood: -154027.9098
#   Iteration 50, Log Likelihood: -153990.0230
#   Iteration 60, Log Likelihood: -153977.5213
#   Iteration 70, Log Likelihood: -153975.7399
#   Iteration 80, Log Likelihood: -153975.1987
#   Iteration 90, Log Likelihood: -153974.6876
#   Iteration 100, Log Likelihood: -153973.9179
#   Iteration 110, Log Likelihood: -153972.3100
#   Iteration 120, Log Likelihood: -153968.1693
#   Iteration 130, Log Likelihood: -153961.0429
#   Iteration 140, Log Likelihood: -153957.5735
#   Iteration 150, Log Likelihood: -153956.9125
#   Iteration 160, Log Likelihood: -153956.7819
#   Iteration 170, Log Likelihood: -153956.7490
#   Iteration 180, Log Likelihood: -153956.7391
#   Iteration 190, Log Likelihood: -153956.7358
#   Iteration 200, Log Likelihood: -153956.7347
#   Iteration 210, Log Likelihood: -153956.7343
#   Converged at iteration 219
#   Fitting GMM for class 1...
#   Iteration 1, Log Likelihood: -132708.1829
#   Iteration 10, Log Likelihood: -71838.6698
#   Iteration 20, Log Likelihood: -70411.6760
#   Iteration 30, Log Likelihood: -69738.1507
#   Iteration 40, Log Likelihood: -69477.0164
#   Iteration 50, Log Likelihood: -69308.0972
#   Iteration 60, Log Likelihood: -69197.9112
#   Iteration 70, Log Likelihood: -69143.6562
#   Iteration 80, Log Likelihood: -69132.7884
#   Iteration 90, Log Likelihood: -69130.3736
#   Iteration 100, Log Likelihood: -69129.5161
#   Iteration 110, Log Likelihood: -69129.1858
#   Iteration 120, Log Likelihood: -69129.0650
#   Iteration 130, Log Likelihood: -69129.0235
#   Iteration 140, Log Likelihood: -69129.0099
#   Iteration 150, Log Likelihood: -69129.0055
#   Iteration 160, Log Likelihood: -69129.0041
#   Iteration 170, Log Likelihood: -69129.0037
#   Converged at iteration 178
#   Fitting GMM for class 2...
#   Iteration 1, Log Likelihood: -191975.6542
#   Iteration 10, Log Likelihood: -160649.0019
#   Iteration 20, Log Likelihood: -160489.2268
#   Iteration 30, Log Likelihood: -160483.6756
#   Iteration 40, Log Likelihood: -160483.1903
#   Iteration 50, Log Likelihood: -160483.0963
#   Iteration 60, Log Likelihood: -160483.0686
#   Iteration 70, Log Likelihood: -160483.0593
#   Iteration 80, Log Likelihood: -160483.0560
#   Iteration 90, Log Likelihood: -160483.0549
#   Iteration 100, Log Likelihood: -160483.0544
#   Converged at iteration 109
#   Fitting GMM for class 3...
#   Iteration 1, Log Likelihood: -192035.7260
#   Iteration 10, Log Likelihood: -162682.7419
#   Iteration 20, Log Likelihood: -162363.2869
#   Iteration 30, Log Likelihood: -162253.1712
#   Iteration 40, Log Likelihood: -162169.6812
#   Iteration 50, Log Likelihood: -162107.5846
#   Iteration 60, Log Likelihood: -162081.7553
#   Iteration 70, Log Likelihood: -162059.1522
#   Iteration 80, Log Likelihood: -162040.4569
#   Iteration 90, Log Likelihood: -162021.5795
#   Iteration 100, Log Likelihood: -162004.4788
#   Iteration 110, Log Likelihood: -161989.2340
#   Iteration 120, Log Likelihood: -161967.6834
#   Iteration 130, Log Likelihood: -161954.7379
#   Iteration 140, Log Likelihood: -161951.1544
#   Iteration 150, Log Likelihood: -161946.9360
#   Iteration 160, Log Likelihood: -161939.3495
#   Iteration 170, Log Likelihood: -161933.3433
#   Iteration 180, Log Likelihood: -161930.7754
#   Iteration 190, Log Likelihood: -161929.8158
#   Iteration 200, Log Likelihood: -161929.4122
#   Iteration 210, Log Likelihood: -161929.2044
#   Iteration 220, Log Likelihood: -161929.0704
#   Iteration 230, Log Likelihood: -161928.9634
#   Iteration 240, Log Likelihood: -161928.8619
#   Iteration 250, Log Likelihood: -161928.7544
#   Iteration 260, Log Likelihood: -161928.6328
#   Iteration 270, Log Likelihood: -161928.4887
#   Iteration 280, Log Likelihood: -161928.3081
#   Iteration 290, Log Likelihood: -161928.0678
#   Iteration 300, Log Likelihood: -161927.7281
#   Iteration 310, Log Likelihood: -161927.2195
#   Iteration 320, Log Likelihood: -161926.4135
#   Iteration 330, Log Likelihood: -161925.0508
#   Iteration 340, Log Likelihood: -161922.5571
#   Iteration 350, Log Likelihood: -161918.9427
#   Iteration 360, Log Likelihood: -161915.9973
#   Iteration 370, Log Likelihood: -161914.0522
#   Iteration 380, Log Likelihood: -161912.6111
#   Iteration 390, Log Likelihood: -161911.5866
#   Iteration 400, Log Likelihood: -161910.9597
#   Iteration 410, Log Likelihood: -161910.6149
#   Iteration 420, Log Likelihood: -161910.4347
#   Iteration 430, Log Likelihood: -161910.3430
#   Iteration 440, Log Likelihood: -161910.2971
#   Iteration 450, Log Likelihood: -161910.2744
#   Iteration 460, Log Likelihood: -161910.2632
#   Iteration 470, Log Likelihood: -161910.2578
#   Iteration 480, Log Likelihood: -161910.2551
#   Iteration 490, Log Likelihood: -161910.2538
#   Iteration 500, Log Likelihood: -161910.2532
#   Fitting GMM for class 4...
#   Iteration 1, Log Likelihood: -176613.0888
#   Iteration 10, Log Likelihood: -146522.8996
#   Iteration 20, Log Likelihood: -146084.5032
#   Iteration 30, Log Likelihood: -145742.1359
#   Iteration 40, Log Likelihood: -145705.0720
#   Iteration 50, Log Likelihood: -145700.0345
#   Iteration 60, Log Likelihood: -145694.3735
#   Iteration 70, Log Likelihood: -145682.9105
#   Iteration 80, Log Likelihood: -145652.3075
#   Iteration 90, Log Likelihood: -145613.3636
#   Iteration 100, Log Likelihood: -145596.5286
#   Iteration 110, Log Likelihood: -145593.1670
#   Iteration 120, Log Likelihood: -145592.2554
#   Iteration 130, Log Likelihood: -145591.9167
#   Iteration 140, Log Likelihood: -145591.7835
#   Iteration 150, Log Likelihood: -145591.7306
#   Iteration 160, Log Likelihood: -145591.7094
#   Iteration 170, Log Likelihood: -145591.7008
#   Iteration 180, Log Likelihood: -145591.6973
#   Iteration 190, Log Likelihood: -145591.6958
#   Iteration 200, Log Likelihood: -145591.6952
#   Iteration 210, Log Likelihood: -145591.6949
#   Converged at iteration 218
#   Fitting GMM for class 5...
#   Iteration 1, Log Likelihood: -170700.5709
#   Iteration 10, Log Likelihood: -140640.1503
#   Iteration 20, Log Likelihood: -140303.2021
#   Iteration 30, Log Likelihood: -140115.0728
#   Iteration 40, Log Likelihood: -139902.8035
#   Iteration 50, Log Likelihood: -139891.3986
#   Iteration 60, Log Likelihood: -139885.9061
#   Iteration 70, Log Likelihood: -139882.2083
#   Iteration 80, Log Likelihood: -139878.9608
#   Iteration 90, Log Likelihood: -139875.7335
#   Iteration 100, Log Likelihood: -139873.0385
#   Iteration 110, Log Likelihood: -139870.6488
#   Iteration 120, Log Likelihood: -139867.9627
#   Iteration 130, Log Likelihood: -139866.0922
#   Iteration 140, Log Likelihood: -139865.0624
#   Iteration 150, Log Likelihood: -139864.5407
#   Iteration 160, Log Likelihood: -139864.2870
#   Iteration 170, Log Likelihood: -139864.1627
#   Iteration 180, Log Likelihood: -139864.1000
#   Iteration 190, Log Likelihood: -139864.0672
#   Iteration 200, Log Likelihood: -139864.0493
#   Iteration 210, Log Likelihood: -139864.0393
#   Iteration 220, Log Likelihood: -139864.0336
#   Iteration 230, Log Likelihood: -139864.0303
#   Iteration 240, Log Likelihood: -139864.0283
#   Iteration 250, Log Likelihood: -139864.0270
#   Iteration 260, Log Likelihood: -139864.0263
#   Iteration 270, Log Likelihood: -139864.0258
#   Iteration 280, Log Likelihood: -139864.0256
#   Iteration 290, Log Likelihood: -139864.0254
#   Converged at iteration 298
#   Fitting GMM for class 6...
#   Iteration 1, Log Likelihood: -175495.3379
#   Iteration 10, Log Likelihood: -140873.5664
#   Iteration 20, Log Likelihood: -140674.2669
#   Iteration 30, Log Likelihood: -140662.3774
#   Iteration 40, Log Likelihood: -140660.3101
#   Iteration 50, Log Likelihood: -140660.0001
#   Iteration 60, Log Likelihood: -140659.9353
#   Iteration 70, Log Likelihood: -140659.9117
#   Iteration 80, Log Likelihood: -140659.9010
#   Iteration 90, Log Likelihood: -140659.8958
#   Iteration 100, Log Likelihood: -140659.8933
#   Iteration 110, Log Likelihood: -140659.8921
#   Iteration 120, Log Likelihood: -140659.8915
#   Iteration 130, Log Likelihood: -140659.8912
#   Iteration 140, Log Likelihood: -140659.8911
#   Converged at iteration 141
#   Fitting GMM for class 7...
#   Iteration 1, Log Likelihood: -178194.9556
#   Iteration 10, Log Likelihood: -144843.6620
#   Iteration 20, Log Likelihood: -144292.2411
#   Iteration 30, Log Likelihood: -144222.8145
#   Iteration 40, Log Likelihood: -144141.3670
#   Iteration 50, Log Likelihood: -144085.3593
#   Iteration 60, Log Likelihood: -144024.6542
#   Iteration 70, Log Likelihood: -143855.5501
#   Iteration 80, Log Likelihood: -143649.4687
#   Iteration 90, Log Likelihood: -143627.9362
#   Iteration 100, Log Likelihood: -143621.6732
#   Iteration 110, Log Likelihood: -143617.9626
#   Iteration 120, Log Likelihood: -143615.1735
#   Iteration 130, Log Likelihood: -143613.5905
#   Iteration 140, Log Likelihood: -143612.8326
#   Iteration 150, Log Likelihood: -143612.5160
#   Iteration 160, Log Likelihood: -143612.3991
#   Iteration 170, Log Likelihood: -143612.3593
#   Iteration 180, Log Likelihood: -143612.3464
#   Iteration 190, Log Likelihood: -143612.3423
#   Iteration 200, Log Likelihood: -143612.3410
#   Iteration 210, Log Likelihood: -143612.3406
#   Converged at iteration 217
#   Fitting GMM for class 8...
#   Iteration 1, Log Likelihood: -180324.2721
#   Iteration 10, Log Likelihood: -151354.3186
#   Iteration 20, Log Likelihood: -150964.1673
#   Iteration 30, Log Likelihood: -150875.5091
#   Iteration 40, Log Likelihood: -150864.5367
#   Iteration 50, Log Likelihood: -150862.7805
#   Iteration 60, Log Likelihood: -150862.2871
#   Iteration 70, Log Likelihood: -150861.9302
#   Iteration 80, Log Likelihood: -150861.4305
#   Iteration 90, Log Likelihood: -150860.5322
#   Iteration 100, Log Likelihood: -150858.6768
#   Iteration 110, Log Likelihood: -150854.3025
#   Iteration 120, Log Likelihood: -150841.4645
#   Iteration 130, Log Likelihood: -150809.4468
#   Iteration 140, Log Likelihood: -150744.3556
#   Iteration 150, Log Likelihood: -150711.4040
#   Iteration 160, Log Likelihood: -150697.8634
#   Iteration 170, Log Likelihood: -150673.2845
#   Iteration 180, Log Likelihood: -150655.5201
#   Iteration 190, Log Likelihood: -150647.2339
#   Iteration 200, Log Likelihood: -150645.3110
#   Iteration 210, Log Likelihood: -150644.8535
#   Iteration 220, Log Likelihood: -150644.7137
#   Iteration 230, Log Likelihood: -150644.6617
#   Iteration 240, Log Likelihood: -150644.6389
#   Iteration 250, Log Likelihood: -150644.6273
#   Iteration 260, Log Likelihood: -150644.6203
#   Iteration 270, Log Likelihood: -150644.6155
#   Iteration 280, Log Likelihood: -150644.6120
#   Iteration 290, Log Likelihood: -150644.6092
#   Iteration 300, Log Likelihood: -150644.6069
#   Iteration 310, Log Likelihood: -150644.6049
#   Iteration 320, Log Likelihood: -150644.6033
#   Iteration 330, Log Likelihood: -150644.6019
#   Iteration 340, Log Likelihood: -150644.6007
#   Iteration 350, Log Likelihood: -150644.5997
#   Iteration 360, Log Likelihood: -150644.5988
#   Iteration 370, Log Likelihood: -150644.5981
#   Iteration 380, Log Likelihood: -150644.5974
#   Iteration 390, Log Likelihood: -150644.5969
#   Iteration 400, Log Likelihood: -150644.5964
#   Iteration 410, Log Likelihood: -150644.5960
#   Iteration 420, Log Likelihood: -150644.5957
#   Iteration 430, Log Likelihood: -150644.5954
#   Iteration 440, Log Likelihood: -150644.5952
#   Iteration 450, Log Likelihood: -150644.5950
#   Iteration 460, Log Likelihood: -150644.5948
#   Iteration 470, Log Likelihood: -150644.5946
#   Iteration 480, Log Likelihood: -150644.5945
#   Iteration 490, Log Likelihood: -150644.5944
#   Converged at iteration 493
#   Fitting GMM for class 9...
#   Iteration 1, Log Likelihood: -175942.5346
#   Iteration 10, Log Likelihood: -141675.4787
#   Iteration 20, Log Likelihood: -141315.7344
#   Iteration 30, Log Likelihood: -141237.9949
#   Iteration 40, Log Likelihood: -141187.1752
#   Iteration 50, Log Likelihood: -141154.0054
#   Iteration 60, Log Likelihood: -141151.8435
#   Iteration 70, Log Likelihood: -141151.6288
#   Iteration 80, Log Likelihood: -141151.5546
#   Iteration 90, Log Likelihood: -141151.5188
#   Iteration 100, Log Likelihood: -141151.4993
#   Iteration 110, Log Likelihood: -141151.4879
#   Iteration 120, Log Likelihood: -141151.4809
#   Iteration 130, Log Likelihood: -141151.4763
#   Iteration 140, Log Likelihood: -141151.4732
#   Iteration 150, Log Likelihood: -141151.4711
#   Iteration 160, Log Likelihood: -141151.4696
#   Iteration 170, Log Likelihood: -141151.4685
#   Iteration 180, Log Likelihood: -141151.4676
#   Iteration 190, Log Likelihood: -141151.4670
#   Iteration 200, Log Likelihood: -141151.4665
#   Iteration 210, Log Likelihood: -141151.4661
#   Iteration 220, Log Likelihood: -141151.4658
#   Iteration 230, Log Likelihood: -141151.4656
#   Iteration 240, Log Likelihood: -141151.4654
#   Iteration 250, Log Likelihood: -141151.4652
#   Iteration 260, Log Likelihood: -141151.4651
#   Iteration 270, Log Likelihood: -141151.4649
#   Converged at iteration 277
# GMMs fitted.
# Classifying test data...
# Error rate for K=10: 0.0733
#
# Fitting GMMs with K=20 components per class...
#   Fitting GMM for class 0...
#   Iteration 1, Log Likelihood: -183633.0268
#   Iteration 10, Log Likelihood: -148636.7994
#   Iteration 20, Log Likelihood: -147852.8087
#   Iteration 30, Log Likelihood: -147526.1716
#   Iteration 40, Log Likelihood: -147469.8797
#   Iteration 50, Log Likelihood: -147451.2111
#   Iteration 60, Log Likelihood: -147430.5089
#   Iteration 70, Log Likelihood: -147408.2738
#   Iteration 80, Log Likelihood: -147400.7369
#   Iteration 90, Log Likelihood: -147396.3621
#   Iteration 100, Log Likelihood: -147393.4199
#   Iteration 110, Log Likelihood: -147389.2793
#   Iteration 120, Log Likelihood: -147384.8738
#   Iteration 130, Log Likelihood: -147382.9173
#   Iteration 140, Log Likelihood: -147382.0544
#   Iteration 150, Log Likelihood: -147381.1844
#   Iteration 160, Log Likelihood: -147379.5127
#   Iteration 170, Log Likelihood: -147376.1888
#   Iteration 180, Log Likelihood: -147371.7231
#   Iteration 190, Log Likelihood: -147369.1970
#   Iteration 200, Log Likelihood: -147368.6060
#   Iteration 210, Log Likelihood: -147368.4094
#   Iteration 220, Log Likelihood: -147368.3037
#   Iteration 230, Log Likelihood: -147368.2291
#   Iteration 240, Log Likelihood: -147368.1691
#   Iteration 250, Log Likelihood: -147368.1177
#   Iteration 260, Log Likelihood: -147368.0722
#   Iteration 270, Log Likelihood: -147368.0317
#   Iteration 280, Log Likelihood: -147367.9958
#   Iteration 290, Log Likelihood: -147367.9645
#   Iteration 300, Log Likelihood: -147367.9377
#   Iteration 310, Log Likelihood: -147367.9153
#   Iteration 320, Log Likelihood: -147367.8968
#   Iteration 330, Log Likelihood: -147367.8819
#   Iteration 340, Log Likelihood: -147367.8699
#   Iteration 350, Log Likelihood: -147367.8604
#   Iteration 360, Log Likelihood: -147367.8529
#   Iteration 370, Log Likelihood: -147367.8469
#   Iteration 380, Log Likelihood: -147367.8421
#   Iteration 390, Log Likelihood: -147367.8383
#   Iteration 400, Log Likelihood: -147367.8353
#   Iteration 410, Log Likelihood: -147367.8328
#   Iteration 420, Log Likelihood: -147367.8307
#   Iteration 430, Log Likelihood: -147367.8290
#   Iteration 440, Log Likelihood: -147367.8276
#   Iteration 450, Log Likelihood: -147367.8265
#   Iteration 460, Log Likelihood: -147367.8255
#   Iteration 470, Log Likelihood: -147367.8246
#   Iteration 480, Log Likelihood: -147367.8239
#   Iteration 490, Log Likelihood: -147367.8233
#   Iteration 500, Log Likelihood: -147367.8228
#   Fitting GMM for class 1...
#   Iteration 1, Log Likelihood: -125975.8043
#   Iteration 10, Log Likelihood: -56394.3264
#   Iteration 20, Log Likelihood: -55102.6568
#   Iteration 30, Log Likelihood: -54159.1521
#   Iteration 40, Log Likelihood: -53992.5756
#   Iteration 50, Log Likelihood: -53872.6519
#   Iteration 60, Log Likelihood: -53621.5279
#   Iteration 70, Log Likelihood: -53473.8094
#   Iteration 80, Log Likelihood: -53327.2148
#   Iteration 90, Log Likelihood: -53267.1702
#   Iteration 100, Log Likelihood: -53246.7176
#   Iteration 110, Log Likelihood: -53238.6780
#   Iteration 120, Log Likelihood: -53233.4851
#   Iteration 130, Log Likelihood: -53230.8346
#   Iteration 140, Log Likelihood: -53225.3742
#   Iteration 150, Log Likelihood: -53214.2017
#   Iteration 160, Log Likelihood: -53200.9082
#   Iteration 170, Log Likelihood: -53160.3453
#   Iteration 180, Log Likelihood: -53128.4001
#   Iteration 190, Log Likelihood: -53107.0976
#   Iteration 200, Log Likelihood: -53098.1988
#   Iteration 210, Log Likelihood: -53092.6621
#   Iteration 220, Log Likelihood: -53088.6307
#   Iteration 230, Log Likelihood: -53084.4630
#   Iteration 240, Log Likelihood: -53082.1877
#   Iteration 250, Log Likelihood: -53079.4656
#   Iteration 260, Log Likelihood: -53069.0352
#   Iteration 270, Log Likelihood: -53059.2997
#   Iteration 280, Log Likelihood: -53056.2479
#   Iteration 290, Log Likelihood: -53055.1171
#   Iteration 300, Log Likelihood: -53054.5908
#   Iteration 310, Log Likelihood: -53054.2653
#   Iteration 320, Log Likelihood: -53054.0530
#   Iteration 330, Log Likelihood: -53053.9240
#   Iteration 340, Log Likelihood: -53053.8473
#   Iteration 350, Log Likelihood: -53053.7986
#   Iteration 360, Log Likelihood: -53053.7640
#   Iteration 370, Log Likelihood: -53053.7367
#   Iteration 380, Log Likelihood: -53053.7136
#   Iteration 390, Log Likelihood: -53053.6932
#   Iteration 400, Log Likelihood: -53053.6748
#   Iteration 410, Log Likelihood: -53053.6584
#   Iteration 420, Log Likelihood: -53053.6440
#   Iteration 430, Log Likelihood: -53053.6316
#   Iteration 440, Log Likelihood: -53053.6212
#   Iteration 450, Log Likelihood: -53053.6129
#   Iteration 460, Log Likelihood: -53053.6063
#   Iteration 470, Log Likelihood: -53053.6014
#   Iteration 480, Log Likelihood: -53053.5978
#   Iteration 490, Log Likelihood: -53053.5952
#   Iteration 500, Log Likelihood: -53053.5934
#   Fitting GMM for class 2...
#   Iteration 1, Log Likelihood: -184655.4586
#   Iteration 10, Log Likelihood: -156117.0106
#   Iteration 20, Log Likelihood: -155541.4982
#   Iteration 30, Log Likelihood: -155375.8447
#   Iteration 40, Log Likelihood: -155239.8901
#   Iteration 50, Log Likelihood: -155002.6876
#   Iteration 60, Log Likelihood: -154883.4274
#   Iteration 70, Log Likelihood: -154859.3548
#   Iteration 80, Log Likelihood: -154839.4697
#   Iteration 90, Log Likelihood: -154826.6896
#   Iteration 100, Log Likelihood: -154822.8202
#   Iteration 110, Log Likelihood: -154821.7981
#   Iteration 120, Log Likelihood: -154821.4214
#   Iteration 130, Log Likelihood: -154821.2368
#   Iteration 140, Log Likelihood: -154821.1302
#   Iteration 150, Log Likelihood: -154821.0620
#   Iteration 160, Log Likelihood: -154821.0150
#   Iteration 170, Log Likelihood: -154820.9809
#   Iteration 180, Log Likelihood: -154820.9548
#   Iteration 190, Log Likelihood: -154820.9342
#   Iteration 200, Log Likelihood: -154820.9173
#   Iteration 210, Log Likelihood: -154820.9032
#   Iteration 220, Log Likelihood: -154820.8911
#   Iteration 230, Log Likelihood: -154820.8805
#   Iteration 240, Log Likelihood: -154820.8712
#   Iteration 250, Log Likelihood: -154820.8627
#   Iteration 260, Log Likelihood: -154820.8549
#   Iteration 270, Log Likelihood: -154820.8477
#   Iteration 280, Log Likelihood: -154820.8409
#   Iteration 290, Log Likelihood: -154820.8345
#   Iteration 300, Log Likelihood: -154820.8284
#   Iteration 310, Log Likelihood: -154820.8225
#   Iteration 320, Log Likelihood: -154820.8167
#   Iteration 330, Log Likelihood: -154820.8111
#   Iteration 340, Log Likelihood: -154820.8055
#   Iteration 350, Log Likelihood: -154820.8000
#   Iteration 360, Log Likelihood: -154820.7944
#   Iteration 370, Log Likelihood: -154820.7889
#   Iteration 380, Log Likelihood: -154820.7833
#   Iteration 390, Log Likelihood: -154820.7775
#   Iteration 400, Log Likelihood: -154820.7717
#   Iteration 410, Log Likelihood: -154820.7656
#   Iteration 420, Log Likelihood: -154820.7592
#   Iteration 430, Log Likelihood: -154820.7524
#   Iteration 440, Log Likelihood: -154820.7450
#   Iteration 450, Log Likelihood: -154820.7368
#   Iteration 460, Log Likelihood: -154820.7275
#   Iteration 470, Log Likelihood: -154820.7167
#   Iteration 480, Log Likelihood: -154820.7036
#   Iteration 490, Log Likelihood: -154820.6873
#   Iteration 500, Log Likelihood: -154820.6666
#   Fitting GMM for class 3...
#   Iteration 1, Log Likelihood: -186014.9739
#   Iteration 10, Log Likelihood: -157419.1951
#   Iteration 20, Log Likelihood: -156703.0112
#   Iteration 30, Log Likelihood: -156499.8867
#   Iteration 40, Log Likelihood: -156454.2539
#   Iteration 50, Log Likelihood: -156433.2382
#   Iteration 60, Log Likelihood: -156415.9857
#   Iteration 70, Log Likelihood: -156387.3715
#   Iteration 80, Log Likelihood: -156320.6158
#   Iteration 90, Log Likelihood: -156290.5399
#   Iteration 100, Log Likelihood: -156280.4607
#   Iteration 110, Log Likelihood: -156272.4694
#   Iteration 120, Log Likelihood: -156265.3473
#   Iteration 130, Log Likelihood: -156261.8583
#   Iteration 140, Log Likelihood: -156257.4595
#   Iteration 150, Log Likelihood: -156253.1836
#   Iteration 160, Log Likelihood: -156251.8888
#   Iteration 170, Log Likelihood: -156251.6613
#   Iteration 180, Log Likelihood: -156251.6049
#   Iteration 190, Log Likelihood: -156251.5825
#   Iteration 200, Log Likelihood: -156251.5703
#   Iteration 210, Log Likelihood: -156251.5625
#   Iteration 220, Log Likelihood: -156251.5570
#   Iteration 230, Log Likelihood: -156251.5527
#   Iteration 240, Log Likelihood: -156251.5492
#   Iteration 250, Log Likelihood: -156251.5462
#   Iteration 260, Log Likelihood: -156251.5433
#   Iteration 270, Log Likelihood: -156251.5405
#   Iteration 280, Log Likelihood: -156251.5375
#   Iteration 290, Log Likelihood: -156251.5340
#   Iteration 300, Log Likelihood: -156251.5296
#   Iteration 310, Log Likelihood: -156251.5235
#   Iteration 320, Log Likelihood: -156251.5139
#   Iteration 330, Log Likelihood: -156251.4960
#   Iteration 340, Log Likelihood: -156251.4529
#   Iteration 350, Log Likelihood: -156251.2933
#   Iteration 360, Log Likelihood: -156250.1292
#   Iteration 370, Log Likelihood: -156243.3651
#   Iteration 380, Log Likelihood: -156233.0529
#   Iteration 390, Log Likelihood: -156228.0324
#   Iteration 400, Log Likelihood: -156224.9809
#   Iteration 410, Log Likelihood: -156222.8793
#   Iteration 420, Log Likelihood: -156221.7764
#   Iteration 430, Log Likelihood: -156221.2768
#   Iteration 440, Log Likelihood: -156221.0625
#   Iteration 450, Log Likelihood: -156220.9729
#   Iteration 460, Log Likelihood: -156220.9365
#   Iteration 470, Log Likelihood: -156220.9219
#   Iteration 480, Log Likelihood: -156220.9161
#   Iteration 490, Log Likelihood: -156220.9138
#   Iteration 500, Log Likelihood: -156220.9129
#   Fitting GMM for class 4...
#   Iteration 1, Log Likelihood: -169183.9463
#   Iteration 10, Log Likelihood: -140624.1664
#   Iteration 20, Log Likelihood: -140030.7937
#   Iteration 30, Log Likelihood: -139817.0153
#   Iteration 40, Log Likelihood: -139753.6505
#   Iteration 50, Log Likelihood: -139692.6068
#   Iteration 60, Log Likelihood: -139618.8742
#   Iteration 70, Log Likelihood: -139453.4203
#   Iteration 80, Log Likelihood: -139330.5973
#   Iteration 90, Log Likelihood: -139312.5361
#   Iteration 100, Log Likelihood: -139298.4627
#   Iteration 110, Log Likelihood: -139286.2875
#   Iteration 120, Log Likelihood: -139266.4748
#   Iteration 130, Log Likelihood: -139248.9532
#   Iteration 140, Log Likelihood: -139226.6881
#   Iteration 150, Log Likelihood: -139205.2992
#   Iteration 160, Log Likelihood: -139200.8761
#   Iteration 170, Log Likelihood: -139200.2506
#   Iteration 180, Log Likelihood: -139200.0644
#   Iteration 190, Log Likelihood: -139199.9872
#   Iteration 200, Log Likelihood: -139199.9502
#   Iteration 210, Log Likelihood: -139199.9314
#   Iteration 220, Log Likelihood: -139199.9218
#   Iteration 230, Log Likelihood: -139199.9167
#   Iteration 240, Log Likelihood: -139199.9141
#   Iteration 250, Log Likelihood: -139199.9126
#   Iteration 260, Log Likelihood: -139199.9119
#   Iteration 270, Log Likelihood: -139199.9114
#   Iteration 280, Log Likelihood: -139199.9112
#   Converged at iteration 290
#   Fitting GMM for class 5...
#   Iteration 1, Log Likelihood: -167689.4003
#   Iteration 10, Log Likelihood: -135585.2942
#   Iteration 20, Log Likelihood: -134823.0201
#   Iteration 30, Log Likelihood: -134675.2753
#   Iteration 40, Log Likelihood: -134611.4234
#   Iteration 50, Log Likelihood: -134563.3197
#   Iteration 60, Log Likelihood: -134523.4861
#   Iteration 70, Log Likelihood: -134484.7900
#   Iteration 80, Log Likelihood: -134462.3642
#   Iteration 90, Log Likelihood: -134449.1267
#   Iteration 100, Log Likelihood: -134430.8075
#   Iteration 110, Log Likelihood: -134400.6523
#   Iteration 120, Log Likelihood: -134375.3749
#   Iteration 130, Log Likelihood: -134363.4171
#   Iteration 140, Log Likelihood: -134355.6265
#   Iteration 150, Log Likelihood: -134324.2187
#   Iteration 160, Log Likelihood: -134289.4327
#   Iteration 170, Log Likelihood: -134286.0859
#   Iteration 180, Log Likelihood: -134284.6388
#   Iteration 190, Log Likelihood: -134283.6044
#   Iteration 200, Log Likelihood: -134282.7184
#   Iteration 210, Log Likelihood: -134281.9060
#   Iteration 220, Log Likelihood: -134281.1548
#   Iteration 230, Log Likelihood: -134280.4960
#   Iteration 240, Log Likelihood: -134279.9562
#   Iteration 250, Log Likelihood: -134279.4623
#   Iteration 260, Log Likelihood: -134279.0111
#   Iteration 270, Log Likelihood: -134278.5104
#   Iteration 280, Log Likelihood: -134277.1023
#   Iteration 290, Log Likelihood: -134267.2106
#   Iteration 300, Log Likelihood: -134225.4913
#   Iteration 310, Log Likelihood: -134200.1714
#   Iteration 320, Log Likelihood: -134193.8891
#   Iteration 330, Log Likelihood: -134193.2819
#   Iteration 340, Log Likelihood: -134193.2152
#   Iteration 350, Log Likelihood: -134193.2065
#   Iteration 360, Log Likelihood: -134193.2051
#   Iteration 370, Log Likelihood: -134193.2047
#   Iteration 380, Log Likelihood: -134193.2045
#   Converged at iteration 388
#   Fitting GMM for class 6...
#   Iteration 1, Log Likelihood: -171964.4466
#   Iteration 10, Log Likelihood: -135247.3478
#   Iteration 20, Log Likelihood: -134403.6608
#   Iteration 30, Log Likelihood: -134243.2959
#   Iteration 40, Log Likelihood: -134158.9537
#   Iteration 50, Log Likelihood: -134069.2742
#   Iteration 60, Log Likelihood: -134038.9823
#   Iteration 70, Log Likelihood: -134020.6799
#   Iteration 80, Log Likelihood: -133991.3261
#   Iteration 90, Log Likelihood: -133977.9807
#   Iteration 100, Log Likelihood: -133971.0280
#   Iteration 110, Log Likelihood: -133962.7306
#   Iteration 120, Log Likelihood: -133957.3237
#   Iteration 130, Log Likelihood: -133955.0616
#   Iteration 140, Log Likelihood: -133952.4661
#   Iteration 150, Log Likelihood: -133943.6354
#   Iteration 160, Log Likelihood: -133942.1792
#   Iteration 170, Log Likelihood: -133942.0711
#   Iteration 180, Log Likelihood: -133942.0235
#   Iteration 190, Log Likelihood: -133941.9889
#   Iteration 200, Log Likelihood: -133941.9602
#   Iteration 210, Log Likelihood: -133941.9347
#   Iteration 220, Log Likelihood: -133941.9112
#   Iteration 230, Log Likelihood: -133941.8891
#   Iteration 240, Log Likelihood: -133941.8680
#   Iteration 250, Log Likelihood: -133941.8473
#   Iteration 260, Log Likelihood: -133941.8268
#   Iteration 270, Log Likelihood: -133941.8060
#   Iteration 280, Log Likelihood: -133941.7848
#   Iteration 290, Log Likelihood: -133941.7627
#   Iteration 300, Log Likelihood: -133941.7395
#   Iteration 310, Log Likelihood: -133941.7148
#   Iteration 320, Log Likelihood: -133941.6885
#   Iteration 330, Log Likelihood: -133941.6600
#   Iteration 340, Log Likelihood: -133941.6287
#   Iteration 350, Log Likelihood: -133941.5936
#   Iteration 360, Log Likelihood: -133941.5531
#   Iteration 370, Log Likelihood: -133941.5043
#   Iteration 380, Log Likelihood: -133941.4428
#   Iteration 390, Log Likelihood: -133941.3616
#   Iteration 400, Log Likelihood: -133941.2494
#   Iteration 410, Log Likelihood: -133941.0861
#   Iteration 420, Log Likelihood: -133940.8185
#   Iteration 430, Log Likelihood: -133940.2469
#   Iteration 440, Log Likelihood: -133938.2746
#   Iteration 450, Log Likelihood: -133923.2215
#   Iteration 460, Log Likelihood: -133914.2692
#   Iteration 470, Log Likelihood: -133911.5429
#   Iteration 480, Log Likelihood: -133910.8539
#   Iteration 490, Log Likelihood: -133910.5991
#   Iteration 500, Log Likelihood: -133910.4701
#   Fitting GMM for class 7...
#   Iteration 1, Log Likelihood: -171449.9367
#   Iteration 10, Log Likelihood: -135887.7107
#   Iteration 20, Log Likelihood: -135358.3755
#   Iteration 30, Log Likelihood: -135180.2530
#   Iteration 40, Log Likelihood: -135034.8321
#   Iteration 50, Log Likelihood: -134992.6015
#   Iteration 60, Log Likelihood: -134941.3244
#   Iteration 70, Log Likelihood: -134896.5280
#   Iteration 80, Log Likelihood: -134872.2091
#   Iteration 90, Log Likelihood: -134832.5680
#   Iteration 100, Log Likelihood: -134792.4402
#   Iteration 110, Log Likelihood: -134721.4353
#   Iteration 120, Log Likelihood: -134687.3239
#   Iteration 130, Log Likelihood: -134658.5676
#   Iteration 140, Log Likelihood: -134633.5621
#   Iteration 150, Log Likelihood: -134626.6702
#   Iteration 160, Log Likelihood: -134617.7810
#   Iteration 170, Log Likelihood: -134612.0614
#   Iteration 180, Log Likelihood: -134605.0223
#   Iteration 190, Log Likelihood: -134596.0438
#   Iteration 200, Log Likelihood: -134587.4515
#   Iteration 210, Log Likelihood: -134585.6854
#   Iteration 220, Log Likelihood: -134585.1202
#   Iteration 230, Log Likelihood: -134584.7634
#   Iteration 240, Log Likelihood: -134584.5412
#   Iteration 250, Log Likelihood: -134584.4061
#   Iteration 260, Log Likelihood: -134584.3066
#   Iteration 270, Log Likelihood: -134584.2228
#   Iteration 280, Log Likelihood: -134584.1519
#   Iteration 290, Log Likelihood: -134584.0958
#   Iteration 300, Log Likelihood: -134584.0570
#   Iteration 310, Log Likelihood: -134584.0343
#   Iteration 320, Log Likelihood: -134584.0227
#   Iteration 330, Log Likelihood: -134584.0173
#   Iteration 340, Log Likelihood: -134584.0149
#   Iteration 350, Log Likelihood: -134584.0137
#   Iteration 360, Log Likelihood: -134584.0129
#   Iteration 370, Log Likelihood: -134584.0123
#   Iteration 380, Log Likelihood: -134584.0117
#   Iteration 390, Log Likelihood: -134584.0111
#   Iteration 400, Log Likelihood: -134584.0102
#   Iteration 410, Log Likelihood: -134584.0093
#   Iteration 420, Log Likelihood: -134584.0081
#   Iteration 430, Log Likelihood: -134584.0068
#   Iteration 440, Log Likelihood: -134584.0052
#   Iteration 450, Log Likelihood: -134584.0035
#   Iteration 460, Log Likelihood: -134584.0016
#   Iteration 470, Log Likelihood: -134583.9995
#   Iteration 480, Log Likelihood: -134583.9974
#   Iteration 490, Log Likelihood: -134583.9953
#   Iteration 500, Log Likelihood: -134583.9932
#   Fitting GMM for class 8...
#   Iteration 1, Log Likelihood: -176506.7142
#   Iteration 10, Log Likelihood: -147413.5985
#   Iteration 20, Log Likelihood: -146908.3046
#   Iteration 30, Log Likelihood: -146592.1506
#   Iteration 40, Log Likelihood: -146306.0697
#   Iteration 50, Log Likelihood: -146241.3770
#   Iteration 60, Log Likelihood: -146196.2565
#   Iteration 70, Log Likelihood: -146148.5777
#   Iteration 80, Log Likelihood: -146067.2108
#   Iteration 90, Log Likelihood: -146043.2948
#   Iteration 100, Log Likelihood: -146036.9287
#   Iteration 110, Log Likelihood: -146033.7059
#   Iteration 120, Log Likelihood: -146031.7989
#   Iteration 130, Log Likelihood: -146030.4549
#   Iteration 140, Log Likelihood: -146029.4777
#   Iteration 150, Log Likelihood: -146028.7424
#   Iteration 160, Log Likelihood: -146028.0904
#   Iteration 170, Log Likelihood: -146027.5147
#   Iteration 180, Log Likelihood: -146027.0825
#   Iteration 190, Log Likelihood: -146026.7731
#   Iteration 200, Log Likelihood: -146026.5344
#   Iteration 210, Log Likelihood: -146026.3228
#   Iteration 220, Log Likelihood: -146026.0991
#   Iteration 230, Log Likelihood: -146025.8103
#   Iteration 240, Log Likelihood: -146025.3523
#   Iteration 250, Log Likelihood: -146024.5795
#   Iteration 260, Log Likelihood: -146023.6347
#   Iteration 270, Log Likelihood: -146023.0342
#   Iteration 280, Log Likelihood: -146022.8297
#   Iteration 290, Log Likelihood: -146022.7667
#   Iteration 300, Log Likelihood: -146022.7422
#   Iteration 310, Log Likelihood: -146022.7294
#   Iteration 320, Log Likelihood: -146022.7211
#   Iteration 330, Log Likelihood: -146022.7151
#   Iteration 340, Log Likelihood: -146022.7105
#   Iteration 350, Log Likelihood: -146022.7068
#   Iteration 360, Log Likelihood: -146022.7038
#   Iteration 370, Log Likelihood: -146022.7012
#   Iteration 380, Log Likelihood: -146022.6990
#   Iteration 390, Log Likelihood: -146022.6971
#   Iteration 400, Log Likelihood: -146022.6953
#   Iteration 410, Log Likelihood: -146022.6938
#   Iteration 420, Log Likelihood: -146022.6924
#   Iteration 430, Log Likelihood: -146022.6912
#   Iteration 440, Log Likelihood: -146022.6900
#   Iteration 450, Log Likelihood: -146022.6890
#   Iteration 460, Log Likelihood: -146022.6880
#   Iteration 470, Log Likelihood: -146022.6872
#   Iteration 480, Log Likelihood: -146022.6863
#   Iteration 490, Log Likelihood: -146022.6856
#   Iteration 500, Log Likelihood: -146022.6849
#   Fitting GMM for class 9...
#   Iteration 1, Log Likelihood: -170042.8215
#   Iteration 10, Log Likelihood: -135764.6920
#   Iteration 20, Log Likelihood: -135140.6364
#   Iteration 30, Log Likelihood: -134981.8631
#   Iteration 40, Log Likelihood: -134937.6330
#   Iteration 50, Log Likelihood: -134869.0817
#   Iteration 60, Log Likelihood: -134761.5387
#   Iteration 70, Log Likelihood: -134697.6525
#   Iteration 80, Log Likelihood: -134686.2710
#   Iteration 90, Log Likelihood: -134676.5358
#   Iteration 100, Log Likelihood: -134667.4157
#   Iteration 110, Log Likelihood: -134662.6241
#   Iteration 120, Log Likelihood: -134657.7940
#   Iteration 130, Log Likelihood: -134652.2121
#   Iteration 140, Log Likelihood: -134642.6885
#   Iteration 150, Log Likelihood: -134629.4804
#   Iteration 160, Log Likelihood: -134621.9687
#   Iteration 170, Log Likelihood: -134614.4302
#   Iteration 180, Log Likelihood: -134603.3228
#   Iteration 190, Log Likelihood: -134592.8255
#   Iteration 200, Log Likelihood: -134588.2878
#   Iteration 210, Log Likelihood: -134587.2272
#   Iteration 220, Log Likelihood: -134586.9099
#   Iteration 230, Log Likelihood: -134586.7987
#   Iteration 240, Log Likelihood: -134586.7557
#   Iteration 250, Log Likelihood: -134586.7353
#   Iteration 260, Log Likelihood: -134586.7215
#   Iteration 270, Log Likelihood: -134586.7080
#   Iteration 280, Log Likelihood: -134586.6903
#   Iteration 290, Log Likelihood: -134586.6609
#   Iteration 300, Log Likelihood: -134586.6008
#   Iteration 310, Log Likelihood: -134586.4593
#   Iteration 320, Log Likelihood: -134586.1832
#   Iteration 330, Log Likelihood: -134585.8921
#   Iteration 340, Log Likelihood: -134585.7135
#   Iteration 350, Log Likelihood: -134585.6167
#   Iteration 360, Log Likelihood: -134585.5569
#   Iteration 370, Log Likelihood: -134585.5161
#   Iteration 380, Log Likelihood: -134585.4870
#   Iteration 390, Log Likelihood: -134585.4653
#   Iteration 400, Log Likelihood: -134585.4481
#   Iteration 410, Log Likelihood: -134585.4336
#   Iteration 420, Log Likelihood: -134585.4203
#   Iteration 430, Log Likelihood: -134585.4075
#   Iteration 440, Log Likelihood: -134585.3941
#   Iteration 450, Log Likelihood: -134585.3795
#   Iteration 460, Log Likelihood: -134585.3627
#   Iteration 470, Log Likelihood: -134585.3428
#   Iteration 480, Log Likelihood: -134585.3189
#   Iteration 490, Log Likelihood: -134585.2901
#   Iteration 500, Log Likelihood: -134585.2559
# GMMs fitted.
# Classifying test data...
# Error rate for K=20: 0.0611
#
# Fitting GMMs with K=30 components per class...
#   Fitting GMM for class 0...
#   Iteration 1, Log Likelihood: -180897.9572
#   Iteration 10, Log Likelihood: -144584.2119
#   Iteration 20, Log Likelihood: -143888.7345
#   Iteration 30, Log Likelihood: -143748.6992
#   Iteration 40, Log Likelihood: -143682.2387
#   Iteration 50, Log Likelihood: -143611.3996
#   Iteration 60, Log Likelihood: -143526.6825
#   Iteration 70, Log Likelihood: -143495.4946
#   Iteration 80, Log Likelihood: -143489.7573
#   Iteration 90, Log Likelihood: -143488.2057
#   Iteration 100, Log Likelihood: -143486.8724
#   Iteration 110, Log Likelihood: -143485.7910
#   Iteration 120, Log Likelihood: -143485.5174
#   Iteration 130, Log Likelihood: -143485.4661
#   Iteration 140, Log Likelihood: -143485.4548
#   Iteration 150, Log Likelihood: -143485.4518
#   Iteration 160, Log Likelihood: -143485.4508
#   Iteration 170, Log Likelihood: -143485.4504
#   Iteration 180, Log Likelihood: -143485.4502
#   Converged at iteration 183
#   Fitting GMM for class 1...
#   Iteration 1, Log Likelihood: -121427.6364
#   Iteration 10, Log Likelihood: -46673.9497
#   Iteration 20, Log Likelihood: -45547.3932
#   Iteration 30, Log Likelihood: -45028.0688
#   Iteration 40, Log Likelihood: -44778.3185
#   Iteration 50, Log Likelihood: -44698.9392
#   Iteration 60, Log Likelihood: -44650.6856
#   Iteration 70, Log Likelihood: -44637.7560
#   Iteration 80, Log Likelihood: -44628.6952
#   Iteration 90, Log Likelihood: -44625.8929
#   Iteration 100, Log Likelihood: -44624.3073
#   Iteration 110, Log Likelihood: -44622.9053
#   Iteration 120, Log Likelihood: -44619.3361
#   Iteration 130, Log Likelihood: -44614.2971
#   Iteration 140, Log Likelihood: -44611.7133
#   Iteration 150, Log Likelihood: -44610.0599
#   Iteration 160, Log Likelihood: -44606.2857
#   Iteration 170, Log Likelihood: -44601.6885
#   Iteration 180, Log Likelihood: -44596.1321
#   Iteration 190, Log Likelihood: -44591.3006
#   Iteration 200, Log Likelihood: -44586.8767
#   Iteration 210, Log Likelihood: -44580.8099
#   Iteration 220, Log Likelihood: -44570.6558
#   Iteration 230, Log Likelihood: -44554.2990
#   Iteration 240, Log Likelihood: -44539.3138
#   Iteration 250, Log Likelihood: -44533.2275
#   Iteration 260, Log Likelihood: -44527.1658
#   Iteration 270, Log Likelihood: -44514.1109
#   Iteration 280, Log Likelihood: -44481.2058
#   Iteration 290, Log Likelihood: -44472.4942
#   Iteration 300, Log Likelihood: -44469.7365
#   Iteration 310, Log Likelihood: -44464.0129
#   Iteration 320, Log Likelihood: -44463.0592
#   Iteration 330, Log Likelihood: -44460.2050
#   Iteration 340, Log Likelihood: -44450.6734
#   Iteration 350, Log Likelihood: -44445.5784
#   Iteration 360, Log Likelihood: -44444.0632
#   Iteration 370, Log Likelihood: -44441.7552
#   Iteration 380, Log Likelihood: -44436.0338
#   Iteration 390, Log Likelihood: -44431.6652
#   Iteration 400, Log Likelihood: -44430.2691
#   Iteration 410, Log Likelihood: -44429.0553
#   Iteration 420, Log Likelihood: -44427.9755
#   Iteration 430, Log Likelihood: -44427.3097
#   Iteration 440, Log Likelihood: -44426.7569
#   Iteration 450, Log Likelihood: -44426.2940
#   Iteration 460, Log Likelihood: -44426.1073
#   Iteration 470, Log Likelihood: -44426.0556
#   Iteration 480, Log Likelihood: -44426.0411
#   Iteration 490, Log Likelihood: -44426.0367
#   Iteration 500, Log Likelihood: -44426.0352
#   Fitting GMM for class 2...
#   Iteration 1, Log Likelihood: -183916.3354
#   Iteration 10, Log Likelihood: -152312.5249
#   Iteration 20, Log Likelihood: -151641.3845
#   Iteration 30, Log Likelihood: -151441.2079
#   Iteration 40, Log Likelihood: -151358.6402
#   Iteration 50, Log Likelihood: -151288.2438
#   Iteration 60, Log Likelihood: -151240.6871
#   Iteration 70, Log Likelihood: -151219.2519
#   Iteration 80, Log Likelihood: -151212.1320
#   Iteration 90, Log Likelihood: -151204.6810
#   Iteration 100, Log Likelihood: -151192.2664
#   Iteration 110, Log Likelihood: -151186.6675
#   Iteration 120, Log Likelihood: -151182.9271
#   Iteration 130, Log Likelihood: -151175.1383
#   Iteration 140, Log Likelihood: -151165.8575
#   Iteration 150, Log Likelihood: -151163.6307
#   Iteration 160, Log Likelihood: -151161.9855
#   Iteration 170, Log Likelihood: -151160.1280
#   Iteration 180, Log Likelihood: -151156.2372
#   Iteration 190, Log Likelihood: -151152.5868
#   Iteration 200, Log Likelihood: -151151.3167
#   Iteration 210, Log Likelihood: -151150.6968
#   Iteration 220, Log Likelihood: -151149.8487
#   Iteration 230, Log Likelihood: -151147.8836
#   Iteration 240, Log Likelihood: -151144.6423
#   Iteration 250, Log Likelihood: -151140.8403
#   Iteration 260, Log Likelihood: -151129.2199
#   Iteration 270, Log Likelihood: -151103.9376
#   Iteration 280, Log Likelihood: -151098.1435
#   Iteration 290, Log Likelihood: -151096.6534
#   Iteration 300, Log Likelihood: -151096.1666
#   Iteration 310, Log Likelihood: -151095.9708
#   Iteration 320, Log Likelihood: -151095.8672
#   Iteration 330, Log Likelihood: -151095.8004
#   Iteration 340, Log Likelihood: -151095.7560
#   Iteration 350, Log Likelihood: -151095.7281
#   Iteration 360, Log Likelihood: -151095.7116
#   Iteration 370, Log Likelihood: -151095.7022
#   Iteration 380, Log Likelihood: -151095.6970
#   Iteration 390, Log Likelihood: -151095.6940
#   Iteration 400, Log Likelihood: -151095.6923
#   Iteration 410, Log Likelihood: -151095.6912
#   Iteration 420, Log Likelihood: -151095.6904
#   Iteration 430, Log Likelihood: -151095.6898
#   Iteration 440, Log Likelihood: -151095.6894
#   Iteration 450, Log Likelihood: -151095.6891
#   Iteration 460, Log Likelihood: -151095.6889
#   Iteration 470, Log Likelihood: -151095.6887
#   Iteration 480, Log Likelihood: -151095.6885
#   Iteration 490, Log Likelihood: -151095.6884
#   Converged at iteration 496
#   Fitting GMM for class 3...
#   Iteration 1, Log Likelihood: -188538.2071
#   Iteration 10, Log Likelihood: -154237.0307
#   Iteration 20, Log Likelihood: -153648.9680
#   Iteration 30, Log Likelihood: -153505.9577
#   Iteration 40, Log Likelihood: -153383.4563
#   Iteration 50, Log Likelihood: -153326.1889
#   Iteration 60, Log Likelihood: -153271.3167
#   Iteration 70, Log Likelihood: -153228.4785
#   Iteration 80, Log Likelihood: -153201.7248
#   Iteration 90, Log Likelihood: -153177.1798
#   Iteration 100, Log Likelihood: -153170.4061
#   Iteration 110, Log Likelihood: -153169.2445
#   Iteration 120, Log Likelihood: -153168.5388
#   Iteration 130, Log Likelihood: -153167.9835
#   Iteration 140, Log Likelihood: -153167.5336
#   Iteration 150, Log Likelihood: -153167.1722
#   Iteration 160, Log Likelihood: -153166.8374
#   Iteration 170, Log Likelihood: -153166.4015
#   Iteration 180, Log Likelihood: -153165.6508
#   Iteration 190, Log Likelihood: -153164.6753
#   Iteration 200, Log Likelihood: -153164.0744
#   Iteration 210, Log Likelihood: -153163.7960
#   Iteration 220, Log Likelihood: -153163.6658
#   Iteration 230, Log Likelihood: -153163.6023
#   Iteration 240, Log Likelihood: -153163.5698
#   Iteration 250, Log Likelihood: -153163.5523
#   Iteration 260, Log Likelihood: -153163.5423
#   Iteration 270, Log Likelihood: -153163.5364
#   Iteration 280, Log Likelihood: -153163.5328
#   Iteration 290, Log Likelihood: -153163.5306
#   Iteration 300, Log Likelihood: -153163.5292
#   Iteration 310, Log Likelihood: -153163.5283
#   Iteration 320, Log Likelihood: -153163.5277
#   Iteration 330, Log Likelihood: -153163.5273
#   Iteration 340, Log Likelihood: -153163.5271
#   Iteration 350, Log Likelihood: -153163.5269
#   Converged at iteration 356
#   Fitting GMM for class 4...
#   Iteration 1, Log Likelihood: -166040.2289
#   Iteration 10, Log Likelihood: -136732.3930
#   Iteration 20, Log Likelihood: -136032.5597
#   Iteration 30, Log Likelihood: -135719.2333
#   Iteration 40, Log Likelihood: -135627.4328
#   Iteration 50, Log Likelihood: -135611.6706
#   Iteration 60, Log Likelihood: -135574.7267
#   Iteration 70, Log Likelihood: -135538.9817
#   Iteration 80, Log Likelihood: -135535.7130
#   Iteration 90, Log Likelihood: -135534.8490
#   Iteration 100, Log Likelihood: -135534.4198
#   Iteration 110, Log Likelihood: -135533.6740
#   Iteration 120, Log Likelihood: -135530.4755
#   Iteration 130, Log Likelihood: -135526.8674
#   Iteration 140, Log Likelihood: -135525.9442
#   Iteration 150, Log Likelihood: -135525.6688
#   Iteration 160, Log Likelihood: -135525.5609
#   Iteration 170, Log Likelihood: -135525.5162
#   Iteration 180, Log Likelihood: -135525.4968
#   Iteration 190, Log Likelihood: -135525.4876
#   Iteration 200, Log Likelihood: -135525.4830
#   Iteration 210, Log Likelihood: -135525.4803
#   Iteration 220, Log Likelihood: -135525.4786
#   Iteration 230, Log Likelihood: -135525.4773
#   Iteration 240, Log Likelihood: -135525.4764
#   Iteration 250, Log Likelihood: -135525.4756
#   Iteration 260, Log Likelihood: -135525.4750
#   Iteration 270, Log Likelihood: -135525.4745
#   Iteration 280, Log Likelihood: -135525.4741
#   Iteration 290, Log Likelihood: -135525.4737
#   Iteration 300, Log Likelihood: -135525.4734
#   Iteration 310, Log Likelihood: -135525.4731
#   Iteration 320, Log Likelihood: -135525.4729
#   Iteration 330, Log Likelihood: -135525.4727
#   Iteration 340, Log Likelihood: -135525.4725
#   Iteration 350, Log Likelihood: -135525.4724
#   Iteration 360, Log Likelihood: -135525.4723
#   Iteration 370, Log Likelihood: -135525.4721
#   Converged at iteration 374
#   Fitting GMM for class 5...
#   Iteration 1, Log Likelihood: -164054.6425
#   Iteration 10, Log Likelihood: -132277.2751
#   Iteration 20, Log Likelihood: -131737.7312
#   Iteration 30, Log Likelihood: -131449.7676
#   Iteration 40, Log Likelihood: -131351.2186
#   Iteration 50, Log Likelihood: -131250.3836
#   Iteration 60, Log Likelihood: -131204.6417
#   Iteration 70, Log Likelihood: -131189.5211
#   Iteration 80, Log Likelihood: -131182.9502
#   Iteration 90, Log Likelihood: -131179.4335
#   Iteration 100, Log Likelihood: -131177.5767
#   Iteration 110, Log Likelihood: -131177.0626
#   Iteration 120, Log Likelihood: -131176.9148
#   Iteration 130, Log Likelihood: -131176.8120
#   Iteration 140, Log Likelihood: -131176.5711
#   Iteration 150, Log Likelihood: -131173.7474
#   Iteration 160, Log Likelihood: -131169.4390
#   Iteration 170, Log Likelihood: -131168.3334
#   Iteration 180, Log Likelihood: -131168.1670
#   Iteration 190, Log Likelihood: -131168.1190
#   Iteration 200, Log Likelihood: -131168.0970
#   Iteration 210, Log Likelihood: -131168.0836
#   Iteration 220, Log Likelihood: -131168.0730
#   Iteration 230, Log Likelihood: -131168.0624
#   Iteration 240, Log Likelihood: -131168.0485
#   Iteration 250, Log Likelihood: -131168.0246
#   Iteration 260, Log Likelihood: -131167.9652
#   Iteration 270, Log Likelihood: -131167.7550
#   Iteration 280, Log Likelihood: -131167.1994
#   Iteration 290, Log Likelihood: -131166.6264
#   Iteration 300, Log Likelihood: -131166.2615
#   Iteration 310, Log Likelihood: -131166.0566
#   Iteration 320, Log Likelihood: -131165.9446
#   Iteration 330, Log Likelihood: -131165.8844
#   Iteration 340, Log Likelihood: -131165.8529
#   Iteration 350, Log Likelihood: -131165.8367
#   Iteration 360, Log Likelihood: -131165.8286
#   Iteration 370, Log Likelihood: -131165.8246
#   Iteration 380, Log Likelihood: -131165.8226
#   Iteration 390, Log Likelihood: -131165.8217
#   Iteration 400, Log Likelihood: -131165.8212
#   Iteration 410, Log Likelihood: -131165.8209
#   Converged at iteration 418
#   Fitting GMM for class 6...
#   Iteration 1, Log Likelihood: -165299.2361
#   Iteration 10, Log Likelihood: -130830.4382
#   Iteration 20, Log Likelihood: -130377.1374
#   Iteration 30, Log Likelihood: -130099.8636
#   Iteration 40, Log Likelihood: -129928.5219
#   Iteration 50, Log Likelihood: -129888.5430
#   Iteration 60, Log Likelihood: -129867.3141
#   Iteration 70, Log Likelihood: -129859.5697
#   Iteration 80, Log Likelihood: -129850.6547
#   Iteration 90, Log Likelihood: -129838.9172
#   Iteration 100, Log Likelihood: -129828.0978
#   Iteration 110, Log Likelihood: -129827.1288
#   Iteration 120, Log Likelihood: -129826.9223
#   Iteration 130, Log Likelihood: -129826.8661
#   Iteration 140, Log Likelihood: -129826.8510
#   Iteration 150, Log Likelihood: -129826.8467
#   Iteration 160, Log Likelihood: -129826.8453
#   Iteration 170, Log Likelihood: -129826.8446
#   Iteration 180, Log Likelihood: -129826.8442
#   Iteration 190, Log Likelihood: -129826.8440
#   Iteration 200, Log Likelihood: -129826.8438
#   Iteration 210, Log Likelihood: -129826.8436
#   Converged at iteration 216
#   Fitting GMM for class 7...
#   Iteration 1, Log Likelihood: -168453.4452
#   Iteration 10, Log Likelihood: -131213.0704
#   Iteration 20, Log Likelihood: -130426.8390
#   Iteration 30, Log Likelihood: -130202.0158
#   Iteration 40, Log Likelihood: -130078.4502
#   Iteration 50, Log Likelihood: -130031.2766
#   Iteration 60, Log Likelihood: -130005.8854
#   Iteration 70, Log Likelihood: -129997.7903
#   Iteration 80, Log Likelihood: -129994.9167
#   Iteration 90, Log Likelihood: -129992.3516
#   Iteration 100, Log Likelihood: -129986.1622
#   Iteration 110, Log Likelihood: -129983.4594
#   Iteration 120, Log Likelihood: -129981.8083
#   Iteration 130, Log Likelihood: -129981.1894
#   Iteration 140, Log Likelihood: -129981.0135
#   Iteration 150, Log Likelihood: -129980.9472
#   Iteration 160, Log Likelihood: -129980.9136
#   Iteration 170, Log Likelihood: -129980.8929
#   Iteration 180, Log Likelihood: -129980.8778
#   Iteration 190, Log Likelihood: -129980.8650
#   Iteration 200, Log Likelihood: -129980.8531
#   Iteration 210, Log Likelihood: -129980.8409
#   Iteration 220, Log Likelihood: -129980.8279
#   Iteration 230, Log Likelihood: -129980.8132
#   Iteration 240, Log Likelihood: -129980.7964
#   Iteration 250, Log Likelihood: -129980.7766
#   Iteration 260, Log Likelihood: -129980.7523
#   Iteration 270, Log Likelihood: -129980.7206
#   Iteration 280, Log Likelihood: -129980.6751
#   Iteration 290, Log Likelihood: -129980.5985
#   Iteration 300, Log Likelihood: -129980.4331
#   Iteration 310, Log Likelihood: -129979.9169
#   Iteration 320, Log Likelihood: -129977.5228
#   Iteration 330, Log Likelihood: -129969.2633
#   Iteration 340, Log Likelihood: -129961.6557
#   Iteration 350, Log Likelihood: -129952.2013
#   Iteration 360, Log Likelihood: -129937.4989
#   Iteration 370, Log Likelihood: -129928.7109
#   Iteration 380, Log Likelihood: -129925.1526
#   Iteration 390, Log Likelihood: -129923.7422
#   Iteration 400, Log Likelihood: -129922.8205
#   Iteration 410, Log Likelihood: -129920.7273
#   Iteration 420, Log Likelihood: -129910.4976
#   Iteration 430, Log Likelihood: -129893.9922
#   Iteration 440, Log Likelihood: -129886.2980
#   Iteration 450, Log Likelihood: -129884.9659
#   Iteration 460, Log Likelihood: -129884.4148
#   Iteration 470, Log Likelihood: -129884.0192
#   Iteration 480, Log Likelihood: -129882.1643
#   Iteration 490, Log Likelihood: -129878.9164
#   Iteration 500, Log Likelihood: -129876.4022
#   Fitting GMM for class 8...
#   Iteration 1, Log Likelihood: -172672.6906
#   Iteration 10, Log Likelihood: -144489.2003
#   Iteration 20, Log Likelihood: -143860.9681
#   Iteration 30, Log Likelihood: -143753.5398
#   Iteration 40, Log Likelihood: -143708.9236
#   Iteration 50, Log Likelihood: -143677.9971
#   Iteration 60, Log Likelihood: -143655.7204
#   Iteration 70, Log Likelihood: -143597.5400
#   Iteration 80, Log Likelihood: -143514.9238
#   Iteration 90, Log Likelihood: -143481.2095
#   Iteration 100, Log Likelihood: -143445.4332
#   Iteration 110, Log Likelihood: -143410.2482
#   Iteration 120, Log Likelihood: -143366.2246
#   Iteration 130, Log Likelihood: -143319.3563
#   Iteration 140, Log Likelihood: -143291.2736
#   Iteration 150, Log Likelihood: -143279.5325
#   Iteration 160, Log Likelihood: -143268.1975
#   Iteration 170, Log Likelihood: -143256.5484
#   Iteration 180, Log Likelihood: -143246.4928
#   Iteration 190, Log Likelihood: -143241.6142
#   Iteration 200, Log Likelihood: -143236.4706
#   Iteration 210, Log Likelihood: -143232.3477
#   Iteration 220, Log Likelihood: -143229.4303
#   Iteration 230, Log Likelihood: -143227.0138
#   Iteration 240, Log Likelihood: -143226.0506
#   Iteration 250, Log Likelihood: -143225.5925
#   Iteration 260, Log Likelihood: -143225.1888
#   Iteration 270, Log Likelihood: -143224.7121
#   Iteration 280, Log Likelihood: -143224.1042
#   Iteration 290, Log Likelihood: -143223.3020
#   Iteration 300, Log Likelihood: -143222.1516
#   Iteration 310, Log Likelihood: -143220.6440
#   Iteration 320, Log Likelihood: -143219.4677
#   Iteration 330, Log Likelihood: -143218.9201
#   Iteration 340, Log Likelihood: -143218.4539
#   Iteration 350, Log Likelihood: -143217.7824
#   Iteration 360, Log Likelihood: -143217.4414
#   Iteration 370, Log Likelihood: -143217.3234
#   Iteration 380, Log Likelihood: -143217.2746
#   Iteration 390, Log Likelihood: -143217.2510
#   Iteration 400, Log Likelihood: -143217.2369
#   Iteration 410, Log Likelihood: -143217.2263
#   Iteration 420, Log Likelihood: -143217.2170
#   Iteration 430, Log Likelihood: -143217.2080
#   Iteration 440, Log Likelihood: -143217.1993
#   Iteration 450, Log Likelihood: -143217.1906
#   Iteration 460, Log Likelihood: -143217.1820
#   Iteration 470, Log Likelihood: -143217.1734
#   Iteration 480, Log Likelihood: -143217.1650
#   Iteration 490, Log Likelihood: -143217.1566
#   Iteration 500, Log Likelihood: -143217.1485
#   Fitting GMM for class 9...
#   Iteration 1, Log Likelihood: -167630.6672
#   Iteration 10, Log Likelihood: -132067.4324
#   Iteration 20, Log Likelihood: -131578.2701
#   Iteration 30, Log Likelihood: -131414.9587
#   Iteration 40, Log Likelihood: -131264.4403
#   Iteration 50, Log Likelihood: -131144.0962
#   Iteration 60, Log Likelihood: -131060.1871
#   Iteration 70, Log Likelihood: -130993.7716
#   Iteration 80, Log Likelihood: -130958.0901
#   Iteration 90, Log Likelihood: -130930.3190
#   Iteration 100, Log Likelihood: -130922.0158
#   Iteration 110, Log Likelihood: -130915.5892
#   Iteration 120, Log Likelihood: -130906.7088
#   Iteration 130, Log Likelihood: -130889.5179
#   Iteration 140, Log Likelihood: -130879.6627
#   Iteration 150, Log Likelihood: -130876.4193
#   Iteration 160, Log Likelihood: -130875.7934
#   Iteration 170, Log Likelihood: -130875.5993
#   Iteration 180, Log Likelihood: -130875.4963
#   Iteration 190, Log Likelihood: -130875.4257
#   Iteration 200, Log Likelihood: -130875.3683
#   Iteration 210, Log Likelihood: -130875.3129
#   Iteration 220, Log Likelihood: -130875.2507
#   Iteration 230, Log Likelihood: -130875.1716
#   Iteration 240, Log Likelihood: -130875.0595
#   Iteration 250, Log Likelihood: -130874.8852
#   Iteration 260, Log Likelihood: -130874.5905
#   Iteration 270, Log Likelihood: -130874.0728
#   Iteration 280, Log Likelihood: -130873.2293
#   Iteration 290, Log Likelihood: -130872.1539
#   Iteration 300, Log Likelihood: -130871.1744
#   Iteration 310, Log Likelihood: -130870.4537
#   Iteration 320, Log Likelihood: -130869.8888
#   Iteration 330, Log Likelihood: -130869.3966
#   Iteration 340, Log Likelihood: -130868.9702
#   Iteration 350, Log Likelihood: -130868.3653
#   Iteration 360, Log Likelihood: -130864.2926
#   Iteration 370, Log Likelihood: -130848.8680
#   Iteration 380, Log Likelihood: -130842.7840
#   Iteration 390, Log Likelihood: -130838.7877
#   Iteration 400, Log Likelihood: -130837.3354
#   Iteration 410, Log Likelihood: -130837.1190
#   Iteration 420, Log Likelihood: -130837.0537
#   Iteration 430, Log Likelihood: -130837.0132
#   Iteration 440, Log Likelihood: -130836.9781
#   Iteration 450, Log Likelihood: -130836.9541
#   Iteration 460, Log Likelihood: -130836.9431
#   Iteration 470, Log Likelihood: -130836.9389
#   Iteration 480, Log Likelihood: -130836.9374
#   Iteration 490, Log Likelihood: -130836.9368
#   Iteration 500, Log Likelihood: -130836.9366
# GMMs fitted.
# Classifying test data...
# Error rate for K=30: 0.0512

# %%
print("\nSummary of Error Rates:")
for K in K_values:
    print(f"  K={K}: Error Rate = {error_rates[K]:.4f}")
# Out:
# Summary of Error Rates:
#   K=5: Error Rate = 0.0882
#   K=10: Error Rate = 0.0733
#   K=20: Error Rate = 0.0611
#   K=30: Error Rate = 0.0512
